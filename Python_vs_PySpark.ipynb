# %%
# Read csv in pandas
import pandas as pd
pdf = pd.read_csv("/dbfs/FileStore/tables/Iris.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Read csv in Spark
sdf = spark.read \
  .options(infer_schema = True, header = True) \
  .csv("/FileStore/tables/Iris.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Print dataframe using pandas
pdf.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>SepalLengthCm</th>
#       <th>SepalWidthCm</th>
#       <th>PetalLengthCm</th>
#       <th>PetalWidthCm</th>
#       <th>Species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>5.1</td>
#       <td>3.5</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>4.9</td>
#       <td>3.0</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4.7</td>
#       <td>3.2</td>
#       <td>1.3</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>4.6</td>
#       <td>3.1</td>
#       <td>1.5</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>5.0</td>
#       <td>3.6</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Print dataframe using spark
sdf.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-------------+------------+-------------+------------+-----------+
#  Id|SepalLengthCm|SepalWidthCm|PetalLengthCm|PetalWidthCm|    Species|
# +---+-------------+------------+-------------+------------+-----------+
#   1|          5.1|         3.5|          1.4|         0.2|Iris-setosa|
#   2|          4.9|         3.0|          1.4|         0.2|Iris-setosa|
#   3|          4.7|         3.2|          1.3|         0.2|Iris-setosa|
#   4|          4.6|         3.1|          1.5|         0.2|Iris-setosa|
#   5|          5.0|         3.6|          1.4|         0.2|Iris-setosa|
# +---+-------------+------------+-------------+------------+-----------+
# only showing top 5 rows
#
# </div>

# %%
# Get column names and datatypes using pandas
pdf.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[35]: Index([&#39;Id&#39;, &#39;SepalLengthCm&#39;, &#39;SepalWidthCm&#39;, &#39;PetalLengthCm&#39;, &#39;PetalWidthCm&#39;,
#        &#39;Species&#39;],
#       dtype=&#39;object&#39;)</div>

# %%
# Get column names and datatypes using pandas
sdf.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: [&#39;Id&#39;,
#  &#39;SepalLengthCm&#39;,
#  &#39;SepalWidthCm&#39;,
#  &#39;PetalLengthCm&#39;,
#  &#39;PetalWidthCm&#39;,
#  &#39;Species&#39;]</div>

# %%
# Get column datatypes in pandas
pdf.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[37]: Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object</div>

# %%
# Get column datatypes in spark
sdf.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: [(&#39;Id&#39;, &#39;string&#39;),
#  (&#39;SepalLengthCm&#39;, &#39;string&#39;),
#  (&#39;SepalWidthCm&#39;, &#39;string&#39;),
#  (&#39;PetalLengthCm&#39;, &#39;string&#39;),
#  (&#39;PetalWidthCm&#39;, &#39;string&#39;),
#  (&#39;Species&#39;, &#39;string&#39;)]</div>

# %%
# Renaming a column in pandas
pdf.rename(columns = {"Species":"Species_new"}).head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>SepalLengthCm</th>
#       <th>SepalWidthCm</th>
#       <th>PetalLengthCm</th>
#       <th>PetalWidthCm</th>
#       <th>Species_new</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>5.1</td>
#       <td>3.5</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>4.9</td>
#       <td>3.0</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4.7</td>
#       <td>3.2</td>
#       <td>1.3</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>4.6</td>
#       <td>3.1</td>
#       <td>1.5</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>5.0</td>
#       <td>3.6</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Renaming a column in spark
sdf.withColumnRenamed("Species", "Species_new").show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-------------+------------+-------------+------------+-----------+
#  Id|SepalLengthCm|SepalWidthCm|PetalLengthCm|PetalWidthCm|Species_new|
# +---+-------------+------------+-------------+------------+-----------+
#   1|          5.1|         3.5|          1.4|         0.2|Iris-setosa|
#   2|          4.9|         3.0|          1.4|         0.2|Iris-setosa|
#   3|          4.7|         3.2|          1.3|         0.2|Iris-setosa|
#   4|          4.6|         3.1|          1.5|         0.2|Iris-setosa|
#   5|          5.0|         3.6|          1.4|         0.2|Iris-setosa|
# +---+-------------+------------+-------------+------------+-----------+
# only showing top 5 rows
#
# </div>

# %%
# Get shape of the table using pandas
pdf.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[41]: (150, 6)</div>

# %%
# Get shape of the table using spark
sdf.count(), len(sdf.columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: (150, 6)</div>

# %%
# Filter columns in pandas
pdf_filtered = pdf[pdf.SepalLengthCm > 2]
pdf_filtered.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>SepalLengthCm</th>
#       <th>SepalWidthCm</th>
#       <th>PetalLengthCm</th>
#       <th>PetalWidthCm</th>
#       <th>Species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>5.1</td>
#       <td>3.5</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>4.9</td>
#       <td>3.0</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4.7</td>
#       <td>3.2</td>
#       <td>1.3</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>4.6</td>
#       <td>3.1</td>
#       <td>1.5</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>5.0</td>
#       <td>3.6</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Filter columns in spark
sdf_filtered = sdf.filter(sdf.SepalLengthCm > 2)
sdf_filtered.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-------------+------------+-------------+------------+-----------+
#  Id|SepalLengthCm|SepalWidthCm|PetalLengthCm|PetalWidthCm|    Species|
# +---+-------------+------------+-------------+------------+-----------+
#   1|          5.1|         3.5|          1.4|         0.2|Iris-setosa|
#   2|          4.9|         3.0|          1.4|         0.2|Iris-setosa|
#   3|          4.7|         3.2|          1.3|         0.2|Iris-setosa|
#   4|          4.6|         3.1|          1.5|         0.2|Iris-setosa|
#   5|          5.0|         3.6|          1.4|         0.2|Iris-setosa|
# +---+-------------+------------+-------------+------------+-----------+
# only showing top 5 rows
#
# </div>

# %%
# Add column in pandas
pdf["SepalLengthCm_new"] = pdf["SepalLengthCm"]*10
pdf.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>SepalLengthCm</th>
#       <th>SepalWidthCm</th>
#       <th>PetalLengthCm</th>
#       <th>PetalWidthCm</th>
#       <th>Species</th>
#       <th>SepalLengthCm_new</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>5.1</td>
#       <td>3.5</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#       <td>51.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>4.9</td>
#       <td>3.0</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#       <td>49.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4.7</td>
#       <td>3.2</td>
#       <td>1.3</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#       <td>47.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>4.6</td>
#       <td>3.1</td>
#       <td>1.5</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#       <td>46.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>5.0</td>
#       <td>3.6</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#       <td>50.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Add column in spark
import pyspark.sql.functions as f
sdf.withColumn("SepalLengthCm_new", sdf.SepalLengthCm * 10).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-------------+------------+-------------+------------+-----------+-----------------+
#  Id|SepalLengthCm|SepalWidthCm|PetalLengthCm|PetalWidthCm|    Species|SepalLengthCm_new|
# +---+-------------+------------+-------------+------------+-----------+-----------------+
#   1|          5.1|         3.5|          1.4|         0.2|Iris-setosa|             51.0|
#   2|          4.9|         3.0|          1.4|         0.2|Iris-setosa|             49.0|
#   3|          4.7|         3.2|          1.3|         0.2|Iris-setosa|             47.0|
#   4|          4.6|         3.1|          1.5|         0.2|Iris-setosa|             46.0|
#   5|          5.0|         3.6|          1.4|         0.2|Iris-setosa|             50.0|
# +---+-------------+------------+-------------+------------+-----------+-----------------+
# only showing top 5 rows
#
# </div>

# %%
# Get unique values of a column in pandas
pdf['Species'].unique()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[47]: array([&#39;Iris-setosa&#39;, &#39;Iris-versicolor&#39;, &#39;Iris-virginica&#39;], dtype=object)</div>

# %%
# Get unique values of a column in spark
sdf.select('Species').distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------+
#         Species|
# +---------------+
#  Iris-virginica|
#     Iris-setosa|
# Iris-versicolor|
# +---------------+
#
# </div>

# %%
# Fill NaNs with pandas
pdf = pdf.fillna(0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Fill NaNs with spark
sdf = sdf.fillna(0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Drop a column in pandas
pdf.drop(["SepalLengthCm_new"], axis=1)
pdf.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>SepalLengthCm</th>
#       <th>SepalWidthCm</th>
#       <th>PetalLengthCm</th>
#       <th>PetalWidthCm</th>
#       <th>Species</th>
#       <th>SepalLengthCm_new</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>5.1</td>
#       <td>3.5</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#       <td>51.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>4.9</td>
#       <td>3.0</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#       <td>49.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>4.7</td>
#       <td>3.2</td>
#       <td>1.3</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#       <td>47.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>4.6</td>
#       <td>3.1</td>
#       <td>1.5</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#       <td>46.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>5.0</td>
#       <td>3.6</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#       <td>50.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Drop a column in spark
sdf.drop("SepalLengthCm_new").columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[52]: [&#39;Id&#39;,
#  &#39;SepalLengthCm&#39;,
#  &#39;SepalWidthCm&#39;,
#  &#39;PetalLengthCm&#39;,
#  &#39;PetalWidthCm&#39;,
#  &#39;Species&#39;]</div>

# %%
# Describe using pandas
pdf.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Id</th>
#       <th>SepalLengthCm</th>
#       <th>SepalWidthCm</th>
#       <th>PetalLengthCm</th>
#       <th>PetalWidthCm</th>
#       <th>SepalLengthCm_new</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>150.000000</td>
#       <td>150.000000</td>
#       <td>150.000000</td>
#       <td>150.000000</td>
#       <td>150.000000</td>
#       <td>150.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>75.500000</td>
#       <td>5.843333</td>
#       <td>3.054000</td>
#       <td>3.758667</td>
#       <td>1.198667</td>
#       <td>58.433333</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>43.445368</td>
#       <td>0.828066</td>
#       <td>0.433594</td>
#       <td>1.764420</td>
#       <td>0.763161</td>
#       <td>8.280661</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.000000</td>
#       <td>4.300000</td>
#       <td>2.000000</td>
#       <td>1.000000</td>
#       <td>0.100000</td>
#       <td>43.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>38.250000</td>
#       <td>5.100000</td>
#       <td>2.800000</td>
#       <td>1.600000</td>
#       <td>0.300000</td>
#       <td>51.000000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>75.500000</td>
#       <td>5.800000</td>
#       <td>3.000000</td>
#       <td>4.350000</td>
#       <td>1.300000</td>
#       <td>58.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>112.750000</td>
#       <td>6.400000</td>
#       <td>3.300000</td>
#       <td>5.100000</td>
#       <td>1.800000</td>
#       <td>64.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>150.000000</td>
#       <td>7.900000</td>
#       <td>4.400000</td>
#       <td>6.900000</td>
#       <td>2.500000</td>
#       <td>79.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Describe using spark
sdf.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+------------------+-------------------+------------------+------------------+--------------+
# summary|                Id|     SepalLengthCm|       SepalWidthCm|     PetalLengthCm|      PetalWidthCm|       Species|
# +-------+------------------+------------------+-------------------+------------------+------------------+--------------+
#   count|               150|               150|                150|               150|               150|           150|
#    mean|              75.5| 5.843333333333335| 3.0540000000000007|3.7586666666666693|1.1986666666666672|          null|
#  stddev|43.445367992456916|0.8280661279778637|0.43359431136217375| 1.764420419952262|0.7631607417008414|          null|
#     min|                 1|               4.3|                2.0|               1.0|               0.1|   Iris-setosa|
#     max|                99|               7.9|                4.4|               6.9|               2.5|Iris-virginica|
# +-------+------------------+------------------+-------------------+------------------+------------------+--------------+
#
# </div>
